# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 20M dataset

# %%
# !ls ml-20m/
# Out:
# README.txt        genome-tags.csv   movies.csv        tags.csv
# genome-scores.csv links.csv         ratings.csv

# %%
path = 'ml-20m/'

# %%
ds_scores = pd.read_csv(path+'genome-scores.csv')
ds_tags = pd.read_csv(path+'genome-tags.csv')
ds_links = pd.read_csv(path+'links.csv')
ds_movies = pd.read_csv(path+'movies.csv')
ds_ratings = pd.read_csv(path+'ratings.csv')
ds_tags = pd.read_csv(path+'tags.csv')

# %%
ds_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
tmp = ds_ratings['movieId'].values
print(tmp.max())
# Out:
# 131262

# %%
uid = ds_ratings['userId']
for id in range(10):
    print(np.sum(uid==id))
# Out:
# 0
# 175
# 61
# 187
# 28
# 66
# 24
# 276
# 70
# 35

# %% [markdown]
# ## 1M dataset

# %%
# !ls ml-1m
# Out:
# README      movies.dat  ratings.dat users.dat

# %%
path = 'ml-1m/'

# %%
movies = pd.read_csv(path+'movies.dat', sep='::', engine='python')
ratings = pd.read_csv(path+'ratings.dat', sep='::', engine='python')
users = pd.read_csv(path+'users.dat', sep='::', engine='python')

# %%
movies.head()
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
users.head()
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455

# %%
#merged = pd.merge(ratings,users)
#merged = pd.merge(merged,movies)

# %%
#merged.head()
# Out:
#    UserID  MovieID  Rating  Timestamp Gender  Age  Occupation Zip-code  \
# 0       1     1193       5  978300760      F    1          10    48067
# 1       2     1193       5  978298413      M   56          16    70072
# 2      12     1193       4  978220179      M   25          12    32793
# 3      15     1193       4  978199279      M   25           7    22903
# 4      17     1193       5  978158471      M   50           1    95350
#
#                                     Title Genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %%
#merged['Gender'] = merged['Gender'].replace(['M','F'],[0,1])

# %%
#genres = ['Action','Adventure','Animation',"Children's",
          'Comedy','Crime','Documentary','Drama','Fantasy',
          'Film-Noir','Horror','Musical','Mystery','Romance',
          'Sci-Fi','Thriller','War','Western']
#genres = ['Action','|Action|','Action|']
#genres_map = [1,1,1]
#genres_map = list(range(18))

# %%
ratings.tail(100)
# Out:
#          UserID  MovieID  Rating  Timestamp
# 1000109    6040     1694       3  956705056
# 1000110    6040     1699       3  963271900
# 1000111    6040     2641       2  956716343
# 1000112    6040     2645       5  960971797
# 1000113    6040     2648       4  957717423
# 1000114    6040     2664       4  957717463
# 1000115    6040     2692       4  956704656
# 1000116    6040      446       4  956704854
# 1000117    6040      448       4  956704788
# 1000118    6040      457       4  997454349
# 1000119    6040     3671       4  997454367
# 1000120    6040     3683       4  960971696
# 1000121    6040     1300       5  956715421
# 1000122    6040     1305       4  956715888
# 1000123    6040     1307       5  956715490
# 1000124    6040      495       2  964828782
# 1000125    6040     1321       3  956715888
# 1000126    6040     1333       4  997454140
# 1000127    6040      800       4  960972032
# 1000128    6040     1354       4  960971992
# ...

# %%
ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
#merged['Genres'] = merged['Genres'].replace(['Action','Action|','|Action','|Action|'],['1','1|','|1','|1|'])

# %%
user = ratings['UserID'].values
movie = ratings['MovieID'].values
rat = ratings['Rating'].values

# %%
from sklearn.neighbors import NearestNeighbors

# %%
def mydist(X, Y):
    m = X.shape[0]
    n = X.shape[0]
    D = np.empty((m,n))
    for i in range(m):
        for j in range(n):
            D[i,j] = 
    return D

# %%
nbrs = NearestNeighbors(n_neighbors=4, algorithm='ball_tree', metric=mydist)

# %%
for i in range(100):
    print(np.sum(uid==i))
